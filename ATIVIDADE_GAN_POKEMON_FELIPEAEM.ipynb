# %% [markdown]
# <a href="https://colab.research.google.com/github/felipeProgrammingDesign/ApplicationBES/blob/master/ATIVIDADE_GAN_POKEMON_FELIPEAEM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install lightweight-gan

# %%
# !nvidia-smi

# %%
# !pip install pytorch-fid
# !mkdir /mountpoint/
# !mount -t tmpfs -o size=80000m tmpfs /mountpoint

# %%
# %cd /mountpoint/
# !pip3 install gdown
# !gdown --id 1zjgNmP0rKuvJJBulUIeXwF-HLlk07IIV

# !unzip pokemon.zip
# !rm -rf pokemon.zip

#Conecte no seu google drive para salvar os modelos e imagens (LEMBRE-SE treinar uma gan demora!). 
#%cd /content/drive/MyDrive/SUA_PASTA/

# %% [markdown]
# Funcionou bem

# %%
# !lightweight_gan --data /mountpoint/pokemon/ --image-size 256 --name POKEMON --batch-size 4 --gradient-accumulate-every 4 --aug-prob 0.25 --aug-types [translation] --calculate-fid-every 1000
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# calculating FID - saving generated:  69% 2222/3200 [01:09<00:30, 32.38it/s]
# calculating FID - saving generated:  70% 2226/3200 [01:09<00:30, 31.62it/s]
# calculating FID - saving generated:  70% 2230/3200 [01:09<00:30, 31.73it/s]
# calculating FID - saving generated:  70% 2234/3200 [01:09<00:29, 32.30it/s]
# calculating FID - saving generated:  70% 2238/3200 [01:09<00:31, 30.92it/s]
# calculating FID - saving generated:  70% 2242/3200 [01:09<00:29, 32.04it/s]
# calculating FID - saving generated:  70% 2246/3200 [01:09<00:29, 32.81it/s]
# calculating FID - saving generated:  70% 2250/3200 [01:09<00:29, 31.84it/s]
# calculating FID - saving generated:  70% 2254/3200 [01:10<00:29, 32.25it/s]
# calculating FID - saving generated:  71% 2258/3200 [01:10<00:29, 31.96it/s]
# calculating FID - saving generated:  71% 2262/3200 [01:10<00:28, 32.43it/s]
# calculating FID - saving generated:  71% 2266/3200 [01:10<00:29, 31.70it/s]
# ...
